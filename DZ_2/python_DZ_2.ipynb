# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
a = input("введите первую строку: ")
b = input("введите вторую строку: ")
if len (long_phrase) > len (short_phrase):
    print("первая строка длиннее")
elif len (long_phrase) > len (short_phrase):
    print("вторая строка длиннее")
print("конец программы")
# Out:
# введите первую строку: Насколько проще было бы писать программы, если бы не заказчики
# введите вторую строку: 640Кб должно хватить для любых задач. Билл Гейтс (по легенде)
# первая строка длиннее
# конец программы

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
number = int(input("Введите объем файла в байтах: "))
b = (number / 1024 / 1024)
print('Объем файла равен, Mb:', b )
# Out:
# Введите объем файла в байтах: 224059719
# Объем файла равен, Mb: 213.67999935150146

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
month = input("Введите месяц рождения: ")
data = int(input("Введите дату рождения: "))
if 1 > data > 31:
    print("Введите корректную дату")
if month == "январь" and 19 >= data >= 1:
    print("Ваш знак: Козерог")
elif month == "январь" and 31 >= data >= 20:
    print("Ваш знак: Водолей")
elif month == "февраль" and 18 >= data >= 1:
    print("Ваш знак: Водолей")
elif month == "февраль" and 28 >= data >= 19:
    print("Ваш знак: Рыбы")
elif month == "март" and 20 >= data >= 1:
    print("Ваш знак: Рыбы")
elif month == "март" and 31 >= data >= 21:
    print("Ваш знак: Овен")
elif month == "апрель" and 19 >= data >= 1:
    print("Ваш знак: Овен")
elif month == "апрель" and 30 >= data >= 20:
    print("Ваш знак: Телец")
elif month == "май" and 20 >= data >= 1:
    print("Ваш знак: Телец")
elif month == "май" and 31 >= data >= 21:
    print("Ваш знак: Близнецы")
elif month == "июнь" and 20 >= data >= 1:
    print("Ваш знак: Близнецы")
elif month == "июнь" and 30 >= data >= 21:
    print("Ваш знак: Рак")
elif month == "июль" and 22 >= data >= 1:
    print("Ваш знак: Рак")
elif month == "июль" and 31 >= data >= 23:
    print("Ваш знак: Лев")
elif month == "август" and 22 >= data >= 1:
    print("Ваш знак: Лев")
elif month == "август" and 31 >= data >= 23:
    print("Ваш знак: Дева")
elif month == "сентябрь" and 22 >= data >= 1:
    print("Ваш знак: Дева")
elif month == "сентябрь" and 30 >= data >= 23:
    print("Ваш знак: Весы")
elif month == "октябрь" and 22 >= data >= 1:
    print("Ваш знак: Весы")
elif month == "октябрь" and 31 >= data >= 23:
    print("Ваш знак: Скорпион")
elif month == "ноябрь" and 21 >= data >= 1:
    print("Ваш знак: Скорпион")
elif month == "ноябрь" and 30 >= data >= 22:
    print("Ваш знак: Стрелец")
elif month == "декабрь" and 21 >= data >= 1:
    print("Ваш знак: Стрелец")
elif month == "декабрь" and 31 >= data >= 22:
    print("Ваш знак: Козерог")
else:
    print("Проверьте правильность ввода месяца и даты")
print("С Вами звезды!")

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
salary_month = int(input("Введите заработную плату в месяц: "))
mortgage = int(input("Введите сколько процентов уходит на ипотеку: "))
life = int(input("Введите сколько процентов уходит на жизнь: "))
bonus_number = int(input("Введите количество премий за год: "))
spend_mortgage = (salary_month * mortgage/100)*12
print("Потрачено на ипотеку за год, рублей: ", spend_mortgage )
salary_total = 12 * salary_month + (salary_month * bonus_number)
spend_total = (12 * salary_month * (mortgage + life)/ 100) + (bonus_number * salary_month / 2)
savings = salary_total - spend_total
print("Пенсионные накопления за год, рублей: ", savings )
# Out:
# Введите заработную плату в месяц: 100000
# Введите сколько процентов уходит на ипотеку: 30
# Введите сколько процентов уходит на жизнь: 50
# Введите количество премий за год: 2
# Потрачено на ипотеку за год, рублей:  360000.0
# Пенсионные накопления за год, рублей:  340000.0
